# %%
import pandas as pd
import os

# %%
path = '/content/drive/MyDrive/UnMazer Assignment'

# %%
listings = pd.read_csv( os.path.join(path, 'listings.csv') )
neighbourhoods = pd.read_csv( os.path.join(path, 'neighbourhoods.csv') )

# %%
print( listings )
print( neighbourhoods )

# %%
#TOP TEN AREAS WITH HIGHEST NUMBER OF LISTINGS

# %%
top_areas = listings[['neighbourhood']].value_counts()[:10]

# %%
top_areas
# Out:
# neighbourhood
# 78704            1822
# 78702            1263
# 78701             713
# 78741             622
# 78703             530
# 78745             513
# 78705             505
# 78751             478
# 78723             313
# 78758             298
# dtype: int64

# %%
#TOP TEN HOSTS WITH HIGHEST NUMBER OF LISTINGS

# %%
topten_hosts = listings[['host_id','host_name']].value_counts()[:10]

# %%
topten_hosts
# Out:
# host_id    host_name
# 359036978  Kia                         358
# 104309976  WanderJaunt                 131
# 109638288  TurnKey Vacation Rentals     82
# 8167447    Martin                       81
# 118565935  Renters Club                 56
# 346827202  Madalynn                     48
# 194953121  Christian                    45
# 210733801  Above                        43
# 368944610  Kia                          40
# 124060715  Evolve Vacation Rental       38
# dtype: int64
